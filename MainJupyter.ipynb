# %%
from utils import *
from A_Star import AStar
from difflib import get_close_matches # Nos permite encontrar la palabra mas cercana a una lista de palabras --> Atenas muy raro en nombres...
import matplotlib.pyplot as plt

G=getAtenas() # Get the Godamm MAP

# %%
torurist=["Atiki","Akropoli","Panourmo"]
result=[]

# %%
result=[]

if(len(torurist)>=2):
    if(len(torurist)>2):
        nodes=G.nodes
        start=get_close_matches(torurist[0],nodes,1)[0]
        for i in range(len(torurist)-1):
            
            #start=get_close_matches(torurist[i],nodes,1)[0] 
            end=get_close_matches(torurist[i+1],nodes,1)[0]

            path=AStar(G,start,end)[0]
            result.extend(path)
            showMapFull(G,path,"magenta")
            
            start=end
        print("Todas las estaciones visitadas")
        print("================================================")
        showMapFull(G,result,"magenta")



    if(len(torurist)==2):
        start=get_close_matches(torurist[0],nodes,1)[0]
        end=get_close_matches(torurist[1],nodes,1)[0]

        path,searchPath=AStar(G,start,end)
        showMapFull(G,searchPath,"magenta")
        showMapFull(G,path,"Lime")
    
else:
    print("You lazy person, give me destinations")
# Out:
# Path from Attiki to Akropoli
# ===========================================
# Path to destiny: ['Akropoli', 'Syntagma', 'Panepistimio', 'Omonia', 'Victoria', 'Attiki']
# Total kilometers: 10.766
# Number of changes: 1
# Path from Akropoli to Panormou
# ===========================================
# Path to destiny: ['Panormou', 'Ambelokipi', 'Megaro Moussikis', 'Evangelismos', 'Syntagma', 'Akropoli']
# Total kilometers: 10.966000000000001
# Number of changes: 1
# Todas las estaciones visitadas
# ================================================

# %%
'''
#####################################################################################
#                                                                                    # 
#                            ,.--------._                                            #
#                           /            ''.                                         #
#                         ,'                \     |"\                /\          /\  #
#                /"|     /                   \    |__"              ( \\        // ) #
#               "_"|    /           z#####z   \  //                  \ \\      // /  #
#                 \\  #####        ##------".  \//                    \_\\||||//_/   #
#                  \\/-----\     /          ".  \                      \/ _  _ \     #
#                   \|      \   |   ,,--..       \                    \/|(O)(O)|     #
#                   | ,.--._ \  (  | ##   \)      \                  \/ |      |     #
#                   |(  ##  )/   \ `-....-//       |///////////////_\/  \      /     #
#                     '--'."      \                \              //     |____|      #
#                  /'    /         ) --.            \            ||     /      \     #
#               ,..|     \.________/    `-..         \   \       \|     \ 0  0 /     #
#            _,##/ |   ,/   /   \           \         \   \       U    / \_//_/      #
#          :###.-  |  ,/   /     \        /' ""\      .\        (     /              #
#         /####|   |   (.___________,---',/    |       |\=._____|  |_/               #
#        /#####|   |     \__|__|__|__|_,/             |####\    |  ||                #
#       /######\   \      \__________/                /#####|   \  ||                #
#      /|#######`. `\                                /#######\   | ||                #
#     /++\#########\  \                      _,'    _/#########\ | ||                #
#    /++++|#########|  \      .---..       ,/      ,'##########.\|_||                #
#   //++++|#########\.  \.              ,-/      ,'########,+++++\\_\\               #
#  /++++++|##########\.   '._        _,/       ,'######,''++++++++\                  #
# |+++++++|###########|       -----."        _'#######' +++++++++++\                 #
# |+++++++|############\.     \\     //      /#######/++++ +++++ +++\                #
#      ________________________\\___//______________________________________         #
#     / ____________________________________________________________________)        #
#    / /              _                                             _                #
#    | |             | |                                           | |               #
#     \ \            | | _           ____           ____           | |  _            #
#      \ \           | || \         / ___)         / _  )          | | / )           #
#  _____) )          | | | |        | |           (  __ /          | |< (            #
# (______/           |_| |_|        |_|            \_____)         |_| \_)           #
#                                                                                    #
######################################################################################
'''
# Out:
# '\n#####################################################################################\n#                                                                                    # \n#                            ,.--------._                                            #\n#                           /            \'\'.                                         #\n#                         ,\'                \\     |"\\                /\\          /\\  #\n#                /"|     /                   \\    |__"              ( \\        // ) #\n#               "_"|    /           z#####z   \\  //                  \\ \\      // /  #\n#                 \\  #####        ##------".  \\//                    \\_\\||||//_/   #\n#                  \\/-----\\     /          ".  \\                      \\/ _  _ \\     #\n#                   \\|      \\   |   ,,--..       \\                    \\/|(O)(O)|     #\n#                   | ,.--._ \\  (  | ##   \\)      \\                  \\/ |      |     #\n#                   |(  ##  )/   \\ `-....-//       |///////////////_\\/  \\      /     #\n#                     \'--\'."      \\                \\              //     |____|      #\n#                  /\'    /         ) --.            \\            ||     /      \\     #\n#               ,..|     \\.________/    `-..         \\   \\       \\|     \\ 0  0 /     #\n#            _,##/ |   ,/   /   \\           \\         \\   \\       U    / \\_//_/      #\n#          :###.-  |  ,/   /     \\        /\' ""\\      .\\        (     /              #\n#         /####|   |   (.___________,---\',/    |       |\\=._____|  |_/               #\n#        /#####|   |     \\__|__|__|__|_,/             |####\\    |  ||                #\n#       /######\\   \\      \\__________/                /#####|   \\  ||                #\n#      /|#######`. `\\                                /#######\\   | ||                #\n#     /++\\#########\\  \\                      _,\'    _/#########\\ | ||                #\n#    /++++|#########|  \\      .---..       ,/      ,\'##########.\\|_||                #\n#   //++++|#########\\.  \\.              ,-/      ,\'########,+++++\\_\\               #\n#  /++++++|##########\\.   \'._        _,/       ,\'######,\'\'++++++++\\                  #\n# |+++++++|###########|       -----."        _\'#######\' +++++++++++\\                 #\n# |+++++++|############\\.     \\     //      /#######/++++ +++++ +++\\                #\n#      ________________________\\___//______________________________________         #\n#     / ____________________________________________________________________)        #\n#    / /              _                                             _                #\n#    | |             | |                                           | |               #\n#     \\ \\            | | _           ____           ____           | |  _            #\n#      \\ \\           | || \\         / ___)         / _  )          | | / )           #\n#  _____) )          | | | |        | |           (  __ /          | |< (            #\n# (______/           |_| |_|        |_|            \\_____)         |_| \\_)           #\n#                                                                                    #\n######################################################################################\n'
